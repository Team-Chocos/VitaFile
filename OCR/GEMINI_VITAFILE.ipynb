# %% [markdown]
# GEMINI API CODE

# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %% [markdown]
# IMPORTING PACKAGES

# %%
# Used to securely store your API key
from google.colab import userdata

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# INSERTING IMAGE

# %%
import PIL.Image

img = PIL.Image.open('jk.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1237>

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(["extract the text in proper way from this image", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# >  Medical Report
# >
# > Patient Name: Mr. SHORYA DWIVEDI
# > Age/Sex: 16 years/Male
# > Ref. By: Dr. Aviral Shailesh (D.M.Pulmonary Medicine)
# > Mobile No.: 6263808020
# > Organization: Sodani Diagnostic (Vijay Nagar)
# >
# > Sample ID: 422102315803
# > Registered: 26 Oct, 2023, 08:18 p.m.
# > Collected On: 26 Oct, 2023, 09:16 p.m.
# > Approved On: 26 Oct, 2023, 09:49 p.m.
# >
# > Test Description	Value(s)	Unit	Reference Range
# > TSH (4th Generation)	2.04	µIU/mL	0.35 - 5.5
# >
# > Method: Atelica/Chemiluminescence
# >
# > Interpretation & Limitation:
# > - Elevated levels of T3 & T4 suppress the production of TSH via negative feedback mechanism. In primary hypothyroidism, T3 & T4 levels are low and TSH levels are elevated. Primary hyperthyroidism (Grave’s disease, thyroid adenoma, nodular goiter) is associated with high levels of thyroid hormones and depressed or undetectable TSH.
# > - The result should be use in conjunction with clinical impression and results of other thyroid tests.
# > - Isolated high TSH specially in the range of 5 to 15 uIU/ml is commonly associated with physiological and biological variability and in recovery phase after non thyroid illness.
# > - Isolated Low TSH- especially in the range of 0.1 to 0.3 often seen in elderly & associated with Non-Thyroidal illness.Performance of this assay has not been established with neonates/premies.
# > - Specimens from the patients who have received preparations of mouse monoclonal antibodies may contain human anti mouse antibody (HAMA), such specimen may show falsely elevated or depressed results.Reference range source: Guidelines of American Thyroid Association during pregnancy and postpartum,2011.
# > - TSH is said to show a diurnal variation with a peak after midnight and nadir in the late afternoon. The variation in TSH is such that the peak value can be double the value at the nadir. The values of TSH can vary by 20% in between measurements without any changes in the thyroid status
# >
# > Associated Test
# > - Free T3 (Triiodothyronine) and Free T4 (Thyroxine) Tests: These tests measure the actual levels of thyroid hormones circulating in the blood and are often used in conjunction with TSH to assess thyroid function more comprehensively.

# %%
response1 = model.generate_content(["Understand what the extracted text is completely and format it in key-value pair with proper indentation", img], stream=True)
response1.resolve()
to_markdown(response1.text)
# Out:
# >  **Patient Information**
# > - Name: Mr. SHORYA DWIVEDI
# > - Age/Sex: 16 years/Male
# > - Referred By: Dr. Aviral Shailesh (D.M.Pulmonary Medicine)
# > - Mobile: 6263808020
# > - Organization: Sodani Diagnostic (Vijay Nagar)
# >
# > **Test Description**
# > - Test: Serum TSH
# > - Value: 2.04 uIU/mL
# > - Unit: uIU/mL
# > - Reference Range: 0.35 - 5.5
# > - Method: Atelica/Chemiluminescence
# >
# > **Interpretation & Limitation**
# > - Elevated levels of T3 & T4 suppress the production of TSH via negative feedback mechanism. In primary hypothyroidism, T3 & T4 levels are low and TSH levels are elevated. Primary hyperthyroidism (Grave’s disease, thyroid adenoma, nodular goiter) is associated with high levels of thyroid hormones and depressed or undetectable TSH.
# > - The result should be used in conjunction with clinical impression and results of other thyroid tests.
# > - Isolated high TSH especially in the range of 5 to 15 uIU/ml is commonly associated with physiological and biological variability and in recovery phase after non thyroid illness.
# > - Isolated Low TSH – especially in the range of 0.1 to 0.3 often seen in elderly & associated with Non – Thyoidal illness.Performance of this assay has not been established with neonates.
# > - Specimens from the patients who have received preparations of mouse monoclonal antibodies may contain human anti mouse antibody (HAMA), such specimen may show falsely elevated or depressed results. Pregnancy reference range source: Guidelines of American Thyroid Association during Pregnancy and postpartum,2011.
# > - TSH is said to show a diurnal variation with a peak after midnight and nadir in the late afternoon. The variation in TSH is such that the peak value can be double the value at the nadir. The values of TSH can vary by 20% in between measurements without any changes in the thyroid status
# >
# > **Associated Test**
# > - Free T3 (Triiodothyronine) and Free T4 (Thyroxine) Tests: These tests measure the actual levels of thyroid hormones circulating in the blood and are often used in conjunction with TSH to assess thyroid function more comprehensively.
